# %% [markdown]
# # Import Dependencies

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sdv.single_table import CTGANSynthesizer
from sdv.metadata import SingleTableMetadata

# %% [markdown]
# # Set Variables

# %%
CULL_FRACTION = 1 #amount of dataset to use
TRAIN_FRACTION = 0.8 #train fraction
LOAD = False #tries to load existing model
EPOCHS = 2500
SAMPLES = 10000 #no of samples to generate
model_path = "models/model.pkl"

# %% [markdown]
# # Load Dataset

# %%
df = pd.read_csv("building_data.csv").set_index("Building Id")  
df = df.drop(columns=['Centroid', 'Post Code', 'State'])

# %% [markdown]
# # Pre Processing

# %%
cull_df = df.sample(frac=CULL_FRACTION).reset_index(drop=True)

train_data, test_data = train_test_split(cull_df, train_size=TRAIN_FRACTION)

print(train_data.shape, test_data.shape)
# Out:
# (320, 15) (80, 15)

# %% [markdown]
# # GAN Training

# %%
metadata = SingleTableMetadata()
metadata.detect_from_dataframe(train_data) 

if LOAD:
    synthesizer = CTGANSynthesizer.load(filepath=model_path)
else:
    synthesizer = CTGANSynthesizer(
        metadata,
        enforce_rounding=True,
        enforce_min_max_values=True,
        epochs=EPOCHS,
        verbose=True
    )
    synthesizer.fit(train_data)
# Out:
# C:\Users\raaja\AppData\Local\Programs\Python\Python311\Lib\site-packages\sdv\single_table\base.py:92: UserWarning: We strongly recommend saving the metadata using 'save_to_json' for replicability in future SDV versions.
#   warnings.warn(
# Gen. (-2.96) | Discrim. (-0.22): 100%|█████████████████████████████████████████████| 2500/2500 [02:16<00:00, 18.37it/s]

# %%
samples = synthesizer.sample(
    num_rows=SAMPLES,
    batch_size=1000
)
samples
# Out:
# Sampling rows: 100%|██████████████████████████████████████████████████████████| 10000/10000 [00:00<00:00, 10035.66it/s]
#             Shape Orientation  Window to Wall Ratio  Height  Surface Area  \
# 0         U-Shape       North                  0.55      15        242.42
# 1         L-Shape       North                  0.42      15        148.82
# 2     Rectangular        East                  0.49      12         78.44
# 3     Rectangular        East                  0.34      12         50.71
# 4     Rectangular        East                  0.38      12        154.37
# ...           ...         ...                   ...     ...           ...
# 9995      U-Shape       South                  0.56      15         74.13
# 9996      L-Shape        East                  0.53      15        306.70
# 9997  Rectangular        East                  0.42      18        128.85
# 9998  Rectangular       South                  0.57      15         85.63
# 9999      U-Shape        West                  0.50      12        121.11
#
#       Material  thickness  set point  Heating System  Cooling System  \
# 0        Steel       0.30         21               0               1
# 1         Wood       0.23         20               1               0
# 2        Steel       0.33         22               1               0
# 3        Steel       0.28         22               1               1
# 4     Concrete       0.22         20               0               0
# ...        ...        ...        ...             ...             ...
# 9995  Concrete       0.27         22               1               1
# 9996     Steel       0.27         22               1               1
# 9997     Steel       0.23         20               1               0
# 9998  Concrete       0.24         19               0               0
# 9999      Wood       0.31         22               1               0
#
#          AC Type  Heater type  PVs  Ceiling fans             Others
# 0       Split AC  Gas Heating    0             1  Microwave, Washer
# 1       Split AC    Heat Pump    1             0  Microwave, Washer
# 2            VRF    Heat Pump    0             2   Oven, Dishwasher
# 3       Split AC  Gas Heating    1             0  Microwave, Washer
# 4            VRF    Heat Pump    1             0   Oven, Dishwasher
# ...          ...          ...  ...           ...                ...
# 9995  Package AC  Gas Heating    1             0  Microwave, Washer
# 9996  Package AC    Heat Pump    1             0   Oven, Dishwasher
# 9997  Package AC    Heat Pump    0             2  Microwave, Washer
# 9998  Package AC  Gas Heating    1             2  Microwave, Washer
# 9999    Split AC    Heat Pump    0             2   Oven, Dishwasher
#
# [10000 rows x 15 columns]

# %% [markdown]
# # Evaluation

# %%
eval_real = test_data.copy()
eval_fake = samples.copy()

le = LabelEncoder()


for column in eval_real.select_dtypes(include=['object']).columns:
    eval_real[column] = le.fit_transform(eval_real[column])

for column in eval_fake.select_dtypes(include=['object']).columns:
    eval_fake[column] = le.fit_transform(eval_fake[column])

# %%
fig = plt.figure(figsize=(5,10))
fig.subplots_adjust(hspace=1, wspace=0.4)

for n,cat in enumerate(eval_real.columns):
    ax = fig.add_subplot(eval_real.shape[1], 1, n+1)
    sns.kdeplot(eval_real[cat], label = 'real', ax=ax)
    sns.kdeplot(eval_fake[cat], label = 'fake', ax = ax)
    plt.legend()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 5
#       2 fig.subplots_adjust(hspace=1, wspace=0.4)
#       4 for n,cat in enumerate(eval_real.columns):
# ----> 5     ax = fig.add_subplot(8, 1, n+1)
#       6     sns.kdeplot(eval_real[cat], label = 'real', ax=ax)
#       7     sns.kdeplot(eval_fake[cat], label = 'fake', ax = ax)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\figure.py:710, in FigureBase.add_subplot(self, *args, **kwargs)
#     708         args = tuple(map(int, str(args[0])))
#     709     projection_class, pkw = self._process_projection_requirements(**kwargs)
# --> 710     ax = projection_class(self, *args, **pkw)
#     711     key = (projection_class, pkw)
#     712 return self._add_axes_internal(ax, key)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\axes\_base.py:640, in _AxesBase.__init__(self, fig, facecolor, frameon, sharex, sharey, label, xscale, yscale, box_aspect, forward_navigation_events, *args, **kwargs)
#     638 else:
#     639     self._position = self._originalPosition = mtransforms.Bbox.unit()
# --> 640     subplotspec = SubplotSpec._from_subplot_args(fig, args)
#     641 if self._position.width < 0 or self._position.height < 0:
#     642     raise ValueError('Width and height specified must be non-negative')
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\gridspec.py:589, in SubplotSpec._from_subplot_args(figure, args)
#     587 else:
#     588     if not isinstance(num, Integral) or num < 1 or num > rows*cols:
# --> 589         raise ValueError(
#     590             f"num must be an integer with 1 <= num <= {rows*cols}, "
#     591             f"not {num!r}"
#     592         )
#     593     i = j = num
#     594 return gs[i-1:j]
#
# ValueError: num must be an integer with 1 <= num <= 8, not 9

# %%
fig_corr = plt.figure(figsize=(20,10))
ax = fig_corr.add_subplot(1, 3, 1)
sns.heatmap(eval_real.corr(), annot=True, ax=ax)
ax = fig_corr.add_subplot(1, 3, 2)
sns.heatmap(eval_fake.corr(), annot=True, ax=ax)
ax = fig_corr.add_subplot(1, 3, 3)
sns.heatmap(abs(eval_real.corr()-eval_fake.corr()), annot=True, ax=ax)
# Out:
# <Axes: >

# %% [markdown]
# # Save Model

# %%
synthesizer.save(filepath=model_path)

# %% [markdown]
# # Save Generated Dataset

# %%
samples.to_csv("generated_data.csv")
