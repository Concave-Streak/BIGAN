# %% [markdown]
# #BIGANS
# ###Building Intelligence with Generative Adversarial Networks

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# DATA Source --> Australian government Department of Bureau of Meteorology
# http://www.bom.gov.au/climate/data/

# %%
max_temp_df = pd.read_csv('Max Temp.csv')
rainfall_df = pd.read_csv('Rainfall.csv')
solar_exposure_df = pd.read_csv('Solar Exposure.csv')

# %%
max_temp_df = max_temp_df[max_temp_df['Year']>1990]
rainfall_df = rainfall_df[(rainfall_df['Year'] > 1990) & (rainfall_df['Year'] < 2021)]
solar_exposure_df = solar_exposure_df[(solar_exposure_df['Year'] > 1990) & (solar_exposure_df['Year'] < 2021)]

# %%
max_temp_df = max_temp_df.reset_index(drop=True)
rainfall_df = rainfall_df.reset_index(drop=True)
solar_exposure_df = solar_exposure_df.reset_index(drop=True)

# %%
max_temp_df.drop(columns=['Product code', 'Bureau of Meteorology station number','Days of accumulation of maximum temperature','Quality'], inplace=True)
rainfall_df.drop(columns=['Product code', 'Bureau of Meteorology station number','Period over which rainfall was measured (days)','Quality'], inplace=True)
solar_exposure_df.drop(columns=['Product code', 'Bureau of Meteorology station number'], inplace=True)

# %%
print(max_temp_df.shape)
print(rainfall_df.shape)
print(solar_exposure_df.shape)
# Out:
# (10835, 4)
# (10958, 4)
# (10958, 4)

# %%
max_temp_df.head()
# Out:
#    Year  Month  Day  Maximum temperature (Degree C)
# 0  1991      1    1                            31.0
# 1  1991      1    2                            29.2
# 2  1991      1    3                            29.9
# 3  1991      1    4                            32.2
# 4  1991      1    5                            35.6

# %%
rainfall_df.head()
# Out:
#    Year  Month  Day  Rainfall amount (millimetres)
# 0  1991      1    1                            0.0
# 1  1991      1    2                            0.0
# 2  1991      1    3                            0.0
# 3  1991      1    4                            0.0
# 4  1991      1    5                            0.0

# %%
solar_exposure_df.head()
# Out:
#    Year  Month  Day  Daily global solar exposure (MJ/m*m)
# 0  1991      1    1                                   NaN
# 1  1991      1    2                                  30.5
# 2  1991      1    3                                  33.3
# 3  1991      1    4                                  32.8
# 4  1991      1    5                                  20.8

# %%
df = pd.merge(max_temp_df, rainfall_df, on=['Year', 'Month', 'Day'], how='inner')
df = pd.merge(df, solar_exposure_df, on=['Year', 'Month', 'Day'], how='inner')

# %%
df
# Out:
#        Year  Month  Day  Maximum temperature (Degree C)  \
# 0      1991      1    1                            31.0
# 1      1991      1    2                            29.2
# 2      1991      1    3                            29.9
# 3      1991      1    4                            32.2
# 4      1991      1    5                            35.6
# ...     ...    ...  ...                             ...
# 10830  2020      8   26                            19.6
# 10831  2020      8   27                            22.2
# 10832  2020      8   28                            19.7
# 10833  2020      8   29                            21.5
# 10834  2020      8   30                            25.3
#
#        Rainfall amount (millimetres)  Daily global solar exposure (MJ/m*m)
# 0                                0.0                                   NaN
# 1                                0.0                                  30.5
# 2                                0.0                                  33.3
# 3                                0.0                                  32.8
# 4                                0.0                                  20.8
# ...                              ...                                   ...
# 10830                            0.0                                  16.7
# 10831                            0.0                                  16.8
# 10832                            0.0                                  17.0
# 10833                            0.0                                  17.1
# 10834                            0.0                                  17.2
#
# [10835 rows x 6 columns]

# %%
df.describe()
# Out:
#                Year         Month           Day  \
# count  10835.000000  10835.000000  10835.000000
# mean    2005.335764      6.477711     15.728565
# std        8.565456      3.440190      8.799862
# min     1991.000000      1.000000      1.000000
# 25%     1998.000000      4.000000      8.000000
# 50%     2005.000000      6.000000     16.000000
# 75%     2013.000000      9.000000     23.000000
# max     2020.000000     12.000000     31.000000
#
#        Maximum temperature (Degree C)  Rainfall amount (millimetres)  \
# count                    10815.000000                   10679.000000
# mean                        22.824595                       3.322062
# std                          4.436295                      10.885159
# min                         10.400000                       0.000000
# 25%                         19.500000                       0.000000
# 50%                         22.700000                       0.000000
# 75%                         25.800000                       1.200000
# max                         45.800000                     264.000000
#
#        Daily global solar exposure (MJ/m*m)
# count                          10425.000000
# mean                              16.295127
# std                                7.896226
# min                                0.100000
# 25%                               10.500000
# 50%                               15.000000
# 75%                               22.300000
# max                               34.900000

# %% [markdown]
# Source of floor area mean -> Australian Bureau Of Statistics https://www.abs.gov.au/articles/average-floor-area-new-residential-dwellings

# %%
#Building area Means of different years
mean_area = [[2002, 245.1], [2003, 249.7], [2004, 247.8],[2005,259.7],[2006,270.4],[2007,250.2],[2008,265.2],[2009,257.8],[2010,255.4],[2011,260.5],
 [2012,256.3],[2013,243],[2014,	238.5],[2015,226.9],[2016,230.6],[2017,220.4],[2018,	221.8],[2019,	235],[2020,224.9]]
mean_area_df = pd.DataFrame(mean_area, columns=['Year', 'Area'])
mean_area_df.head()
# Out:
#    Year   Area
# 0  2002  245.1
# 1  2003  249.7
# 2  2004  247.8
# 3  2005  259.7
# 4  2006  270.4

# %%
def generate_bulding_area():
  num_increments = np.random.randint((1000 - 50) // 10)
  area = 50 + num_increments * 10
  return area

# %%
def generate_building_height():
  num_increments = np.random.randint((15 - 3) // 3 + 1)
  height = 3 + num_increments * 3
  return height

# %%
def generate_building_type():
  categories = ['Single house', 'Townhouse', 'Duplex', 'Apartment']
  cat = np.random.choice(categories)
  return cat

# %%
import random

def find_energy(area, height, b_type, temp, rain, solar):
    # Generate random weights for the input values within a narrower range
    weight1 = random.uniform(0.7, 1.3)
    weight2 = random.uniform(0.7, 1.3)
    weight3 = random.uniform(0.7, 1.3)
    weight4 = random.uniform(0.7, 1.3)
    weight5 = random.uniform(0.7, 1.3)

    # Calculate the weighted mean of the three values
    weighted_mean = (area * weight1 + height * weight2 + b_type * weight3 + rain * weight4 + solar * weight5 ) / (weight1 + weight2 + weight3)

    # Add a random offset to the weighted mean value within a narrower range
    random_offset = random.uniform(-10, 10)  # Adjusted range
    weighted_mean += random_offset

    # Round the weighted mean to the nearest multiple of 10 within the range of 50 to 300
    energy = max(min(round(weighted_mean, -1), 300), 50)
    return energy

# %%
gen_df = df

# %%
def add_building_area(row):
    row['Building Area'] = generate_bulding_area()
    return row
gen_df = gen_df.apply(add_building_area, axis=1)
gen_df
# Out:
#          Year  Month   Day  Maximum temperature (Degree C)  \
# 0      1991.0    1.0   1.0                            31.0
# 1      1991.0    1.0   2.0                            29.2
# 2      1991.0    1.0   3.0                            29.9
# 3      1991.0    1.0   4.0                            32.2
# 4      1991.0    1.0   5.0                            35.6
# ...       ...    ...   ...                             ...
# 10830  2020.0    8.0  26.0                            19.6
# 10831  2020.0    8.0  27.0                            22.2
# 10832  2020.0    8.0  28.0                            19.7
# 10833  2020.0    8.0  29.0                            21.5
# 10834  2020.0    8.0  30.0                            25.3
#
#        Rainfall amount (millimetres)  Daily global solar exposure (MJ/m*m)  \
# 0                                0.0                                   NaN
# 1                                0.0                                  30.5
# 2                                0.0                                  33.3
# 3                                0.0                                  32.8
# 4                                0.0                                  20.8
# ...                              ...                                   ...
# 10830                            0.0                                  16.7
# 10831                            0.0                                  16.8
# 10832                            0.0                                  17.0
# 10833                            0.0                                  17.1
# 10834                            0.0                                  17.2
#
#        Building Area
# 0              920.0
# 1              350.0
# 2              180.0
# 3              690.0
# 4              620.0
# ...              ...
# 10830          260.0
# 10831          140.0
# 10832          390.0
# 10833           60.0
# 10834          980.0
#
# [10835 rows x 7 columns]

# %%
def add_building_height(row):
    row['Building Height'] = generate_building_height()
    return row
gen_df = gen_df.apply(add_building_height, axis=1)
gen_df
# Out:
#          Year  Month   Day  Maximum temperature (Degree C)  \
# 0      1991.0    1.0   1.0                            31.0
# 1      1991.0    1.0   2.0                            29.2
# 2      1991.0    1.0   3.0                            29.9
# 3      1991.0    1.0   4.0                            32.2
# 4      1991.0    1.0   5.0                            35.6
# ...       ...    ...   ...                             ...
# 10830  2020.0    8.0  26.0                            19.6
# 10831  2020.0    8.0  27.0                            22.2
# 10832  2020.0    8.0  28.0                            19.7
# 10833  2020.0    8.0  29.0                            21.5
# 10834  2020.0    8.0  30.0                            25.3
#
#        Rainfall amount (millimetres)  Daily global solar exposure (MJ/m*m)  \
# 0                                0.0                                   NaN
# 1                                0.0                                  30.5
# 2                                0.0                                  33.3
# 3                                0.0                                  32.8
# 4                                0.0                                  20.8
# ...                              ...                                   ...
# 10830                            0.0                                  16.7
# 10831                            0.0                                  16.8
# 10832                            0.0                                  17.0
# 10833                            0.0                                  17.1
# 10834                            0.0                                  17.2
#
#        Building Area  Building Height
# 0              920.0             12.0
# 1              350.0              6.0
# 2              180.0             12.0
# 3              690.0              3.0
# 4              620.0              3.0
# ...              ...              ...
# 10830          260.0              3.0
# 10831          140.0              3.0
# 10832          390.0              9.0
# 10833           60.0              6.0
# 10834          980.0              6.0
#
# [10835 rows x 8 columns]

# %%
def add_building_type(row):
    row['Building Type'] = generate_building_type()
    return row
gen_df = gen_df.apply(add_building_type, axis=1)
gen_df
# Out:
#          Year  Month   Day  Maximum temperature (Degree C)  \
# 0      1991.0    1.0   1.0                            31.0
# 1      1991.0    1.0   2.0                            29.2
# 2      1991.0    1.0   3.0                            29.9
# 3      1991.0    1.0   4.0                            32.2
# 4      1991.0    1.0   5.0                            35.6
# ...       ...    ...   ...                             ...
# 10830  2020.0    8.0  26.0                            19.6
# 10831  2020.0    8.0  27.0                            22.2
# 10832  2020.0    8.0  28.0                            19.7
# 10833  2020.0    8.0  29.0                            21.5
# 10834  2020.0    8.0  30.0                            25.3
#
#        Rainfall amount (millimetres)  Daily global solar exposure (MJ/m*m)  \
# 0                                0.0                                   NaN
# 1                                0.0                                  30.5
# 2                                0.0                                  33.3
# 3                                0.0                                  32.8
# 4                                0.0                                  20.8
# ...                              ...                                   ...
# 10830                            0.0                                  16.7
# 10831                            0.0                                  16.8
# 10832                            0.0                                  17.0
# 10833                            0.0                                  17.1
# 10834                            0.0                                  17.2
#
#        Building Area  Building Height Building Type
# 0              920.0             12.0        Duplex
# 1              350.0              6.0     Townhouse
# 2              180.0             12.0  Single house
# 3              690.0              3.0     Apartment
# 4              620.0              3.0     Townhouse
# ...              ...              ...           ...
# 10830          260.0              3.0        Duplex
# 10831          140.0              3.0  Single house
# 10832          390.0              9.0     Townhouse
# 10833           60.0              6.0     Townhouse
# 10834          980.0              6.0        Duplex
#
# [10835 rows x 9 columns]

# %%
# gen_df.drop(columns=['Buidling Type','Buidling Area','Buidling Height'],inplace=True)
gen_df = gen_df.fillna(df.mean())

# %%
def add_building_energy(row):
    if row['Building Type']=='Single house':
       a = 1
    if row['Building Type']=='Townhouse':
       a = 5
    if row['Building Type']=='Duplex':
       a = 2
    if row['Building Type']=='Apartment':
       a = 10
    row['Buidling Energy'] = find_energy(row['Building Area'],row['Building Height'],a, row['Maximum temperature (Degree C)'], row['Rainfall amount (millimetres)'],row['Daily global solar exposure (MJ/m*m)'])
    return row
gen_df = gen_df.apply(add_building_energy, axis=1)
gen_df
# Out:
#          Year  Month   Day  Maximum temperature (Degree C)  \
# 0      1991.0    1.0   1.0                            31.0
# 1      1991.0    1.0   2.0                            29.2
# 2      1991.0    1.0   3.0                            29.9
# 3      1991.0    1.0   4.0                            32.2
# 4      1991.0    1.0   5.0                            35.6
# ...       ...    ...   ...                             ...
# 10830  2020.0    8.0  26.0                            19.6
# 10831  2020.0    8.0  27.0                            22.2
# 10832  2020.0    8.0  28.0                            19.7
# 10833  2020.0    8.0  29.0                            21.5
# 10834  2020.0    8.0  30.0                            25.3
#
#        Rainfall amount (millimetres)  Daily global solar exposure (MJ/m*m)  \
# 0                                0.0                             16.295127
# 1                                0.0                             30.500000
# 2                                0.0                             33.300000
# 3                                0.0                             32.800000
# 4                                0.0                             20.800000
# ...                              ...                                   ...
# 10830                            0.0                             16.700000
# 10831                            0.0                             16.800000
# 10832                            0.0                             17.000000
# 10833                            0.0                             17.100000
# 10834                            0.0                             17.200000
#
#        Building Area  Building Height Building Type  Buidling Energy
# 0              920.0             12.0        Duplex            260.0
# 1              350.0              6.0     Townhouse            130.0
# 2              180.0             12.0  Single house             70.0
# 3              690.0              3.0     Apartment            190.0
# 4              620.0              3.0     Townhouse            220.0
# ...              ...              ...           ...              ...
# 10830          260.0              3.0        Duplex             80.0
# 10831          140.0              3.0  Single house             70.0
# 10832          390.0              9.0     Townhouse            140.0
# 10833           60.0              6.0     Townhouse             50.0
# 10834          980.0              6.0        Duplex            300.0
#
# [10835 rows x 10 columns]

# %%
gen_df.describe()
# Out:
#                Year         Month           Day  \
# count  10835.000000  10835.000000  10835.000000
# mean    2005.335764      6.477711     15.728565
# std        8.565456      3.440190      8.799862
# min     1991.000000      1.000000      1.000000
# 25%     1998.000000      4.000000      8.000000
# 50%     2005.000000      6.000000     16.000000
# 75%     2013.000000      9.000000     23.000000
# max     2020.000000     12.000000     31.000000
#
#        Maximum temperature (Degree C)  Rainfall amount (millimetres)  \
# count                    10835.000000                   10835.000000
# mean                        22.824595                       3.322062
# std                          4.432198                      10.806506
# min                         10.400000                       0.000000
# 25%                         19.500000                       0.000000
# 50%                         22.700000                       0.000000
# 75%                         25.800000                       1.400000
# max                         45.800000                     264.000000
#
#        Daily global solar exposure (MJ/m*m)  Building Area  Building Height  \
# count                          10835.000000   10835.000000     10835.000000
# mean                              16.295127     520.699585         9.020489
# std                                7.745373     274.765797         4.222375
# min                                0.100000      50.000000         3.000000
# 25%                               10.700000     290.000000         6.000000
# 50%                               15.400000     520.000000         9.000000
# 75%                               21.900000     760.000000        12.000000
# max                               34.900000     990.000000        15.000000
#
#        Buidling Energy
# count     10835.000000
# mean        179.864329
# std          85.299752
# min          50.000000
# 25%         100.000000
# 50%         180.000000
# 75%         260.000000
# max         300.000000

# %%
gen_df.shape
# Out:
# (10835, 10)

# %%
gen_df.isnull().sum()
# Out:
# Year                                    0
# Month                                   0
# Day                                     0
# Maximum temperature (Degree C)          0
# Rainfall amount (millimetres)           0
# Daily global solar exposure (MJ/m*m)    0
# Building Area                           0
# Building Height                         0
# Building Type                           0
# Buidling Energy                         0
# dtype: int64

# %%
final_df  = gen_df.drop(columns=['Year','Month','Day'])
final_df
# Out:
#        Maximum temperature (Degree C)  Rainfall amount (millimetres)  \
# 0                                31.0                            0.0
# 1                                29.2                            0.0
# 2                                29.9                            0.0
# 3                                32.2                            0.0
# 4                                35.6                            0.0
# ...                               ...                            ...
# 10830                            19.6                            0.0
# 10831                            22.2                            0.0
# 10832                            19.7                            0.0
# 10833                            21.5                            0.0
# 10834                            25.3                            0.0
#
#        Daily global solar exposure (MJ/m*m)  Building Area  Building Height  \
# 0                                 16.295127          920.0             12.0
# 1                                 30.500000          350.0              6.0
# 2                                 33.300000          180.0             12.0
# 3                                 32.800000          690.0              3.0
# 4                                 20.800000          620.0              3.0
# ...                                     ...            ...              ...
# 10830                             16.700000          260.0              3.0
# 10831                             16.800000          140.0              3.0
# 10832                             17.000000          390.0              9.0
# 10833                             17.100000           60.0              6.0
# 10834                             17.200000          980.0              6.0
#
#       Building Type  Buidling Energy
# 0            Duplex            260.0
# 1         Townhouse            130.0
# 2      Single house             70.0
# 3         Apartment            190.0
# 4         Townhouse            220.0
# ...             ...              ...
# 10830        Duplex             80.0
# 10831  Single house             70.0
# 10832     Townhouse            140.0
# 10833     Townhouse             50.0
# 10834        Duplex            300.0
#
# [10835 rows x 7 columns]

# %% [markdown]
# ##Synthetic Data Generation Using GANS
